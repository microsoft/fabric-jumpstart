# %%
import logging

# Configure root logger to propagate all messages
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)

# Set fabric_jumpstart to DEBUG (this affects all child loggers)
#logging.getLogger('fabric_jumpstart').setLevel(logging.DEBUG)
logging.getLogger('fabric_jumpstart.core').setLevel(logging.DEBUG)

# %%
from fabric_jumpstart import jumpstart
jumpstart.list()
# Out:
#     <style>
#         * {
#             box-sizing: border-box;
#         }
#         .jumpstart-container {
#             font-family: 'Segoe UI', -apple-system, BlinkMacSystemFont, 'Roboto', 'Helvetica Neue', sans-serif;
#             max-width: 1400px;
#             margin: 0 auto;
#             padding: 40px 20px;
#             background: #fafafa;
#         }
#         .jumpstart-header {
#             margin-bottom: 40px;
#         }
#         .jumpstart-label {
#             color: #0067b6;
#             font-size: 16px;
#             font-weight: 600;
#             text-transform: uppercase;
#             letter-spacing: 2.25px;
#             margin-bottom: 8px;
#         }
#         .jumpstart-header h1 {
#             color: #1f1f1f;
#             font-size: 32px;
#             margin: 0 0 12px 0;
#             font-weight: 700;
#             line-height: 1.2;
#         }
#         .jumpstart-header p {
#             color: #605e5c;
#             font-size: 18px;
#             font-weight: 350;
#             margin: 0;
#             line-height: 1.5;
#         }
#
#         /* Toggle button group */
#         .view-toggle {
#             display: flex;
#             margin-bottom: 20px;
#         }
#         .toggle-group {
#             display: inline-flex;
#             border: 1px solid #d2d0ce;
#             border-radius: 4px;
#             overflow: hidden;
#         }
#         .toggle-group button {
#             background: transparent;
#             color: #323130;
#             border: none;
#             padding: 10px 32px;
#             font-size: 14px;
#             font-weight: 600;
#             cursor: pointer;
#             transition: all 0.2s;
#             border-right: 1px solid #d2d0ce;
#         }
#         .toggle-group button:last-child {
#             border-right: none;
#         }
#         .toggle-group button.active {
#             background: linear-gradient(135deg, #0067b6 0%, #005a9e 100%);
#             color: white;
#         }
#         .toggle-group button:hover:not(.active) {
#             background: #ffffff;
#         }
#
#         /* Tag filter pills */
#         .tag-filters {
#             display: flex;
#             flex-wrap: wrap;
#             gap: 10px;
#             margin-bottom: 40px;
#         }
#         .tag-filter-btn {
#             background: transparent;
#             color: #323130;
#             border: 1px solid #d2d0ce;
#             padding: 6px 18px;
#             border-radius: 4px;
#             font-size: 13px;
#             font-weight: 500;
#             cursor: pointer;
#             transition: all 0.2s;
#         }
#         .tag-filter-btn:hover {
#             background: #ffffff;
#             border-color: #8a8886;
#         }
#         .tag-filter-btn.active {
#             background: linear-gradient(135deg, #0067b6 0%, #005a9e 100%);
#             color: white;
#             border-color: transparent;
#         }
#
#         .category-section {
#             margin-bottom: 60px;
#         }
#         .category-section.hidden {
#             display: none;
#         }
#         .category-label {
#             color: #0067b6;
#             font-size: 16px;
#             font-weight: 600;
#             text-transform: uppercase;
#             letter-spacing: 2.25px;
#             margin-bottom: 4px;
#         }
#         .category-title {
#             color: #1f1f1f;
#             font-size: 24px;
#             font-weight: 700;
#             margin: 0 0 30px 0;
#             line-height: 1.2;
#         }
#         .jumpstart-grid {
#             display: grid;
#             grid-template-columns: repeat(auto-fill, minmax(300px, 1fr));
#             gap: 20px;
#         }
#         .jumpstart-card {
#             background: #ffffff;
#             border: 1px solid #edebe9;
#             border-radius: 4px;
#             overflow: hidden;
#             transition: all 0.3s ease;
#             box-shadow: 0 1.6px 3.6px 0 rgba(0,0,0,.132), 0 0.3px 0.9px 0 rgba(0,0,0,.108);
#             display: flex;
#             flex-direction: column;
#             position: relative;
#         }
#         .jumpstart-card:hover {
#             box-shadow: 0 6.4px 14.4px 0 rgba(0,0,0,.132), 0 1.2px 3.6px 0 rgba(0,0,0,.108);
#             transform: translateY(-2px);
#         }
#         .jumpstart-image {
#             width: 100%;
#             height: 160px;
#             position: relative;
#             background: linear-gradient(135deg, #0067b6 0%, #106ebe 100%);
#             display: flex;
#             align-items: center;
#             justify-content: center;
#         }
#         .jumpstart-new-badge {
#             position: absolute;
#             top: 12px;
#             right: 12px;
#             background: #107c10;
#             color: white;
#             padding: 4px 12px;
#             border-radius: 2px;
#             font-size: 11px;
#             font-weight: 700;
#             text-transform: uppercase;
#             letter-spacing: 0.5px;
#         }
#         .jumpstart-content {
#             padding: 24px;
#             flex: 1;
#             display: flex;
#             flex-direction: column;
#         }
#         .jumpstart-name {
#             color: #1f1f1f;
#             font-size: 1.5em;
#             font-weight: 600;
#             margin-bottom: 12px;
#             line-height: 1.3;
#         }
#         .jumpstart-description {
#             color: #605e5c;
#             font-size: 14px;
#             line-height: 1.6;
#             margin-bottom: 20px;
#             flex: 1;
#         }
#         .jumpstart-install {
#             font-family: 'Consolas', 'Courier New', monospace;
#             font-size: 13px;
#             padding: 12px 16px;
#             background: #f3f2f1;
#             border-radius: 2px;
#             border-left: 3px solid #0067b6;
#             cursor: pointer;
#             transition: background 0.2s;
#             position: relative;
#         }
#         .jumpstart-install:hover {
#             background: #edebe9;
#         }
#         .jumpstart-install:hover .copy-btn {
#             opacity: 1;
#         }
#         .jumpstart-install code {
#             color: #0067b6;
#             background: transparent;
#             font-family: inherit;
#         }
#         .copy-btn {
#             position: absolute;
#             right: 8px;
#             top: 50%;
#             transform: translateY(-50%);
#             background: transparent;
#             border: none;
#             padding: 4px;
#             cursor: pointer;
#             opacity: 0;
#             transition: all 0.2s;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#         }
#         .copy-btn:hover {
#             background: rgba(0, 0, 0, 0.05);
#             border-radius: 2px;
#         }
#         .copy-btn svg {
#             width: 18px;
#             height: 18px;
#             fill: #424242;
#         }
#         .copy-btn.copied svg {
#             fill: #107c10;
#         }
#         .view-container {
#             display: none;
#         }
#         .view-container.active {
#             display: block;
#         }
#     </style>
#
#     <script>
#         function toggleView(viewType, clickedButton) {
#             // Show selected view
#             document.querySelectorAll('.view-container').forEach(el => {
#                 el.classList.remove('active');
#             });
#             document.getElementById(viewType + '-view').classList.add('active');
#
#             // Update toggle button states
#             document.querySelectorAll('.toggle-group button').forEach(btn => {
#                 btn.classList.remove('active');
#             });
#             clickedButton.classList.add('active');
#
#             // Show corresponding tag filters
#             document.querySelectorAll('.tag-filter-row').forEach(row => {
#                 row.style.display = 'none';
#             });
#             document.getElementById(viewType + '-tags').style.display = 'flex';
#
#             // Reset tag filters - show all
#             filterByTag(null, viewType);
#         }
#
#         function filterByTag(tag, viewType, clickedButton) {
#             const view = document.getElementById(viewType + '-view');
#             const sections = view.querySelectorAll('.category-section');
#             const tagB

# %%
jumpstart._load_registry()
# Out:
# 2026-01-09 13:57:07,297 - fabric_jumpstart.core - DEBUG - Jumpstart 'spark-structured-streaming' validated successfully
# 2026-01-09 13:57:07,298 - fabric_jumpstart.core - DEBUG - Jumpstart 'analytics-roadshow-lab' validated successfully
# 2026-01-09 13:57:07,298 - fabric_jumpstart.core - DEBUG - Jumpstart 'sample-test' validated successfully
# 2026-01-09 13:57:07,299 - fabric_jumpstart.core - DEBUG - Jumpstart 'spark-rti-monitoring' validated successfully
# [{'id': 'spark-structured-streaming',
#   'name': 'Spark Structured Streaming',
#   'description': 'Jumpstart for Spark Structured Streaming',
#   'date_added': '1/8/2026',
#   'include_in_listing': True,
#   'workload_tags': ['Data Engineeringing'],
#   'scenario_tags': ['Streaming'],
#   'preview_image': 'assets/image-example.png',
#   'source': {'workspace_path': 'src/', 'repo_url': None, 'repo_ref': 'main'},
#   'items_in_scope': ['Lakehouse',
#    'Warehouse',
#    'Notebook',
#    'SparkJobDefinition',
#    'Environment'],
#   'feature_flags': ['enable_lakehouse_unpublish'],
#   'test_suite': ''},
#  {'id': 'analytics-roadshow-lab',
#   'name': 'Analytics Roadshow Lab',
#   'description': 'Jumpstart for Analytics Roadshow Lab',
#   'date_added': '1/8/2026',
#   'include_in_listing': False,
#   'workload_tags': ['Data Engineering', 'Data Warehouse'],
#   'scenario_tags': ['Streaming', 'Modeling'],
#   'preview_image': 'assets/image-example.png',
#   'source': {'workspace_path': 'workspace/',
#    'repo_url': 'https://github.com/microsoft/fabric-analytics-roadshow-lab.git/',
#    'repo_ref': 'initial-version-prep'},
#   'items_in_scope': ['Lakehouse',
#    'Warehouse',
#    'Notebook',
#    'SparkJobDefinition',
#    'Environment'],
#   'feature_flags': ['enable_lakehouse_unpublish'],
#   'test_suite': ''},
#  {'id': 'sample-test',
#   'name': 'Sample Test',
#   'description': 'Jumpstart for Spark Structured Streaming - monorepo',
#   'date_added': '1/8/2026',
#   'include_in_listing': False,
#   'workload_tags': ['Test'],
#   'scenario_tags': ['Test'],
#   'preview_image': 'assets/image-example.png',
#   'source': {'workspace_path': 'src/', 'repo_url': None, 'repo_ref': 'main'},
#   'items_in_scope': None,
#   'feature_flags': ['enable_lakehouse_unpublish'],
#   'test_suite': ''},
#  {'id': 'spark-rti-monitoring',
#   'name': 'Spark RTI Monitoring',
#   'description': 'Jumpstart for Spark RTI Monitoring',
#   'date_added': '9/1/2026',
#   'include_in_listing': True,
#   'workload_tags': ['Data Engineering', 'Real Time Intelligence'],
#   'scenario_tags': ['Monitoring'],
#   'preview_image': 'assets/image-example.png',
#   'source': {'workspace_path': 'monitoring/fabric-spark-monitoring/src/',
#    'repo_url': 'https://github.com/microsoft/fabric-toolbox.git',
#    'repo_ref': 'f09cb09d26ab317f50a9d97bb833009834661541'},
#   'items_in_scope': ['Notebook',
#    'Eventhouse',
#    'Eventstream',
#    'KQLDatabase',
#    'KQLDashboard',
#    'KQLQueryset',
#    'Environment',
#    'DataPipeline',
#    'Report',
#    'SemanticModel'],
#   'feature_flags': None,
#   'test_suite': None}]

# %%
jumpstart.install(name="sample-test", workspace_id="f863f615-5301-46e4-9654-af55769b39dd")

# %%
jumpstart.install(name="spark-structured-streaming-monorepo", workspace_id="f863f615-5301-46e4-9654-af55769b39dd")

# %%
jumpstart.install(name="analytics-roadshow-lab", workspace_id="f863f615-5301-46e4-9654-af55769b39dd")
# Out:
# 2026-01-08 13:10:32,420 - fabric_jumpstart.core - INFO - Installing 'analytics-roadshow-lab' to workspace 'f863f615-5301-46e4-9654-af55769b39dd'
# 2026-01-08 13:10:32,420 - fabric_jumpstart.core - INFO - Cloning from https://github.com/microsoft/fabric-analytics-roadshow-lab.git/ (ref: initial-version-prep)
# 2026-01-08 13:10:35,023 - fabric_jumpstart.core - INFO - Repository cloned to C:\Users\MILESC~1\AppData\Local\Temp\fabric-jumpstart-ahacrt4f
# 2026-01-08 13:10:35,023 - fabric_jumpstart.core - INFO - Workspace path C:\Users\MILESC~1\AppData\Local\Temp\fabric-jumpstart-ahacrt4f\workspace
# 2026-01-08 13:10:35,023 - fabric_jumpstart.core - INFO - Deploying items from C:\Users\MILESC~1\AppData\Local\Temp\fabric-jumpstart-ahacrt4f\workspace to workspace 'f863f615-5301-46e4-9654-af55769b39dd'
# 2026-01-08 13:10:35,023 - azure.identity._credentials.environment - INFO - No environment configuration found.
# 2026-01-08 13:10:35,023 - azure.identity._credentials.managed_identity - INFO - ManagedIdentityCredential will use IMDS
# 2026-01-08 13:10:35,023 - azure.identity._internal.decorators - DEBUG - EnvironmentCredential.get_token failed: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# Traceback (most recent call last):
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 23, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_credentials\environment.py", line 155, in get_token
#     raise CredentialUnavailableError(message=message)
# azure.identity._exceptions.CredentialUnavailableError: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 2026-01-08 13:10:35,023 - azure.core.pipeline.policies.http_logging_policy - INFO - Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.25.1 Python/3.12.12 (Windows-11-10.0.26200-SP0)'
# No body was attached to the request
# 2026-01-08 13:10:35,023 - urllib3.connectionpool - DEBUG - Starting new HTTP connection (1): 169.254.169.254:80
# 2026-01-08 13:10:36,031 - azure.identity._internal.msal_managed_identity_client - DEBUG - ImdsCredential.get_token failed: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# Traceback (most recent call last):
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 114, in _request_token
#     client.request_token(*scopes, connection_timeout=1, retry_total=0)
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_internal\managed_identity_client.py", line 145, in request_token
#     response = self._pipeline.run(request, retry_on_methods=[request.method], **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 242, in run
#     return first_node.send(pipeline_request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 98, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 98, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 98, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 567, in send
#     raise err
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 545, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 98, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 98, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 98, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 130, in send
#     self._sender.send(request.http_request, **request.context.options),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\transport\_requests_basic.py", line 422, in send
#     raise error
# azure.core.exceptions.ServiceRequestTimeoutError: (<HTTPConnection(host='169.254.169.254', port=80) at 0x1c2e99dfdd0>, 'Connection to 169.254.169.254 timed out. (connect timeout=1)')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_internal\msal_managed_identity_client.py", line 163, in _get_token_base
#     token = self._request_token(*scopes, claims=claims, tenant_id=tenant_id, enable_cae=enable_cae, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 124, in _request_token
#     raise CredentialUnavailableError(error_message) from ex
# azure.identity._exceptions.CredentialUnavailableError: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 2026-01-08 13:10:36,064 - azure.identity._internal.decorators - DEBUG - ManagedIdentityCredential.get_token failed: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# Traceback (most recent call last):
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 114, in _request_token
#     client.request_token(*scopes, connection_timeout=1, retry_total=0)
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_internal\managed_identity_client.py", line 145, in request_token
#     response = self._pipeline.run(request, retry_on_methods=[request.method], **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 242, in run
#     return first_node.send(pipeline_request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 98, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 98, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 98, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 567, in send
#     raise err
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 545, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 98, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 98, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 98, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 130, in send
#     self._sender.send(request.http_request, **request.context.options),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\core\pipeline\transport\_requests_basic.py", line 422, in send
#     raise error
# azure.core.exceptions.ServiceRequestTimeoutError: (<HTTPConnection(host='169.254.169.254', port=80) at 0x1c2e99dfdd0>, 'Connection to 169.254.169.254 timed out. (connect timeout=1)')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 23, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_credentials\managed_identity.py", line 193, in get_token
#     return cast(TokenCredential, self._credential).get_token(*scopes, claims=claims, tenant_id=tenant_id, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_internal\msal_managed_identity_client.py", line 122, in get_token
#     token_info = self._get_token_base(*scopes, options=options, base_method_name="get_token", **kwargs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_internal\msal_managed_identity_client.py", line 163, in _get_token_base
#     token = self._request_token(*scopes, claims=claims, tenant_id=tenant_id, enable_cae=enable_cae, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 124, in _request_token
#     raise CredentialUnavailableError(error_message) from ex
# azure.identity._exceptions.CredentialUnavailableError: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 2026-01-08 13:10:36,064 - azure.identity._internal.decorators - DEBUG - SharedTokenCacheCredential.get_token failed: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# Traceback (most recent call last):
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 23, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_credentials\shared_cache.py", line 85, in get_token
#     return cast(TokenCredential, self._credential).get_token(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_credentials\shared_cache.py", line 152, in get_token
#     token_info = self._get_token_base(*scopes, options=options, base_method_name="get_token", **kwargs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_credentials\shared_cache.py", line 186, in _get_token_base
#     account = self._get_account(self._username, self._tenant_id, is_cae=is_cae)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 75, in wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_internal\shared_token_cache.py", line 209, in _get_account
#     raise CredentialUnavailableError(message=NO_ACCOUNTS)
# azure.identity._exceptions.CredentialUnavailableError: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 2026-01-08 13:10:36,064 - azure.identity._internal.decorators - DEBUG - VisualStudioCodeCredential.get_token failed: VisualStudioCodeCredential requires the 'azure-identity-broker' package to be installed. You must also ensure you have the Azure Resources extension installed and have signed in to Azure via Visual Studio Code.
# Traceback (most recent call last):
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 23, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\milescole\source\fabric-jumpstart\.venv\Lib\site-packages\azure\identity\_credentials\vscode.py", line 211, in get_token
#     raise CredentialUnavailableError(message=self._unavailable_message)
# azure.identity._exceptions.CredentialUnavailableError: VisualStudioCodeCredential requires the 'azure-identity-broker' package to be installed. You must also ensure you have the Azure Resources extension installed and have signed in to Azure via Visual Studio Code.
# 2026-01-08 13:10:36,064 - azure.identity._credentials.azure_cli - DEBUG - Executing subprocess with the following arguments ['C:\\Program Files\\Microsoft SDKs\\Azure\\CLI2\\wbin\\az.cmd', 'account', 'get-access-token', '--output', 'json', '--resource', 'https://api.fabric.microsoft.com']
# 2026-01-08 13:10:37,989 - azure.identity._internal.decorators - DEBUG - AzureCliCredential.get_token succeeded
# 2026-01-08 13:10:37,998 - azure.identity._internal.decorators - DEBUG - [Authenticated account] Client ID: 04b07795-8ddb-461a-bbee-02f9e1bf7b46. Tenant ID: 72f988bf-86f1-41af-91ab-2d7cd011db47. User Principal Name: milescole@microsoft.com. Object ID (user): 1e5808c7-471e-4bcc-9cef-fd9614f7ed63
# 2026-01-08 13:10:37,999 - azure.identity._credentials.chained - INFO - DefaultAzureCredential acquired a token from AzureCliCredential
# [info]   13:10:37 - Executing as User 'milescole@microsoft.com'
# 2026-01-08 13:10:37,999 - fabric_cicd._common._fabric_endpoint - INFO - Executing as User 'milescole@microsoft.com'
# ####################################################################################################
# ########## Validating Parameter File ###############################################################
# ####################################################################################################
# [warn]   13:10:38 - Found the reserved environment key '_ALL_'
# 2026-01-08 13:10:38,699 - fabric_cicd._parameter._parameter - WARNING - Found the reserved environment key '_ALL_'
# [warn]   13:10:39 - The replace value: '$items.Lakehouse.SalesAndLogisticsLH.$id' will be applied for any target environment
# 2026-01-08 13:10:39,489 - fabric_cicd._parameter._parameter - WARNING - The replace value: '$items.Lakehouse.SalesAndLogisticsLH.$id' will be applied for any target environment
# [warn]   13:10:39 - Found the reserved environment key '_ALL_'
# 2026-01-08 13:10:39,489 - fabric_cicd._parameter._parameter - WARNING - Found the reserved environment key '_ALL_'
# [warn]   13:10:39 - The replace value: '$workspace.$id' will be applied for any target environment
# 2026-01-08 13:10:39,489 - fabric_cicd._parameter._parameter - WARNING - The replace value: '$workspace.$id' will be applied for any target environment
# [warn]   13:10:39 - Found the reserved environment key '_ALL_'
# 2026-01-08 13:10:39,489 - fabric_cicd._parameter._parameter - WARNING - Found the reserved environment key '_ALL_'
# [warn]   13:10:39 - The replace value: '$items.Lakehouse.SalesAndLogisticsLH.$id' will be applied for any target environment
# 2026-01-08 13:10:39,489 - fabric_cicd._parameter._parameter - WARNING - The replace value: '$items.Lakehouse.SalesAndLogisticsLH.$id' will be applied for any target environment
# [warn]   13:10:39 - Found the reserved environment key '_ALL_'
# 2026-01-08 13:10:39,489 - fabric_cicd._parameter._parameter - WARNING - Found the reserved environment key '_ALL_'
# [warn]   13:10:39 - The replace value: '$items.Lakehouse.SalesAndLogisticsLH.$id' will be applied for any target environment
# 2026-01-08 13:10:39,489 - fabric_cicd._parameter._parameter - WARNING - The replace value: '$items.Lakehouse.SalesAndLogisticsLH.$id' will be applied for any target environment
# [warn]   13:10:39 - The provided is_regex value is not set to 'true', regex matching will be ignored.
# 2026-01-08 13:10:39,489 - fabric_cicd._parameter._parameter - WARNING - The provided is_regex value is not set to 'true', regex matching will be ignored.
# [warn]   13:10:39 - Found the reserved environment key '_ALL_'
# 2026-01-08 13:10:39,499 - fabric_cicd._parameter._parameter - WARNING - Found the reserved environment key '_ALL_'
# [warn]   13:10:39 - The replace value: '$items.SparkJobDefinition.StreamBronzeAndSilver.$id' will be applied for any target environment
# 2026-01-08 13:10:39,499 - fabric_cicd._parameter._parameter - WARNING - The replace value: '$items.SparkJobDefinition.StreamBronzeAndSilver.$id' will be applied for any target environment
# [warn]   13:10:39 - The provided is_regex value is not set to 'true', regex matching will be ignored.
# 2026-01-08 13:10:39,504 - fabric_cicd._parameter._parameter - WARNING - The provided is_regex value is not set to 'true', regex matching will be ignored.
# [warn]   13:10:39 - Found the reserved environment key '_ALL_'
# 2026-01-08 13:10:39,505 - fabric_cicd._parameter._parameter - WARNING - Found the reserved environment key '_ALL_'
# [warn]   13:10:39 - The replace value: '$workspace.$id' will be applied for any target environment
# 2026-01-08 13:10:39,509 - fabric_cicd._parameter._parameter - WARNING - The replace value: '$workspace.$id' will be applied for any target environment
# [warn]   13:10:39 - Found the reserved environment key '_ALL_'
# 2026-01-08 13:10:39,510 - fabric_cicd._parameter._parameter - WARNING - Found the reserved environment key '_ALL_'
# [warn]   13:10:39 - The replace value: '$items.Warehouse.SalesAndLogisticsWH.$id' will be applied for any target environment
# 2026-01-08 13:10:39,513 - fabric_cicd._parameter._parameter - WARNING - The replace value: '$items.Warehouse.SalesAndLogisticsWH.$id' will be applied for any target environment
# [warn]   13:10:39 - Found the reserved environment key '_ALL_'
# 2026-01-08 13:10:39,514 - fabric_cicd._parameter._parameter - WARNING - Found the reserved environment key '_ALL_'
# [warn]   13:10:39 - The replace value: '$items.Lakehouse.SalesAndLogisticsWH.$id' will be applied for any target environment
# 2026-01-08 13:10:39,516 - fabric_cicd._parameter._parameter - WARNING - The replace value: '$items.Lakehouse.SalesAndLogisticsWH.$id' will be applied for any target environment
# [info]   13:10:39 - Parameter file validation passed
# 2026-01-08 13:10:39,516 - fabric_cicd._parameter._parameter - INFO - Parameter file validation passed
# 2026-01-08 13:10:39,516 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:10:39,999 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd HTTP/1.1" 200 287
# 2026-01-08 13:10:39,999 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:10:40,423 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/folders HTTP/1.1" 200 32
# [info]   13:10:40 - Publishing Workspace Folders
# 2026-01-08 13:10:40,441 - fabric_cicd.fabric_workspace - INFO - Publishing Workspace Folders
#          13:10:40 - Published
# 2026-01-08 13:10:40,441 - fabric_cicd.fabric_workspace - INFO - ->Published
# 2026-01-08 13:10:40,441 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# ####################################################################################################
# ########## Publishing Workspace Folders ############################################################
# ####################################################################################################
# 2026-01-08 13:10:40,972 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/items HTTP/1.1" 200 497
# 2026-01-08 13:10:40,972 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:10:41,631 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/warehouses/cc88a5ac-f557-4e8d-8561-10f7df6a570e HTTP/1.1" 200 403
# 2026-01-08 13:10:41,631 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:10:42,795 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/lakehouses/704e00ae-02bc-4190-ac31-67c3e17ad6f5 HTTP/1.1" 200 428
# 2026-01-08 13:10:42,799 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:10:43,481 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/lakehouses/704e00ae-02bc-4190-ac31-67c3e17ad6f5 HTTP/1.1" 200 428
# [info]   13:10:43 - Publishing Warehouse 'SalesAndLogisticsWH'
# 2026-01-08 13:10:43,939 - fabric_cicd.fabric_workspace - INFO - Publishing Warehouse 'SalesAndLogisticsWH'
# 2026-01-08 13:10:43,954 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# ####################################################################################################
# ########## Publishing Warehouses ###################################################################
# ####################################################################################################
# 2026-01-08 13:10:44,323 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "PATCH /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/items/cc88a5ac-f557-4e8d-8561-10f7df6a570e HTTP/1.1" 200 207
#          13:10:44 - Published
# 2026-01-08 13:10:44,339 - fabric_cicd._items._warehouse - INFO - ->Published
# [info]   13:10:44 - Publishing Lakehouse 'SalesAndLogisticsLH'
# 2026-01-08 13:10:44,339 - fabric_cicd.fabric_workspace - INFO - Publishing Lakehouse 'SalesAndLogisticsLH'
# 2026-01-08 13:10:44,339 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# ####################################################################################################
# ########## Publishing Lakehouses ###################################################################
# ####################################################################################################
# 2026-01-08 13:10:45,540 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "PATCH /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/items/704e00ae-02bc-4190-ac31-67c3e17ad6f5 HTTP/1.1" 200 207
# 2026-01-08 13:10:45,556 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:10:46,139 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/lakehouses/704e00ae-02bc-4190-ac31-67c3e17ad6f5 HTTP/1.1" 200 428
#          13:10:46 - SQL Endpoint provisioned successfully
# 2026-01-08 13:10:46,139 - fabric_cicd._items._lakehouse - INFO - ->SQL Endpoint provisioned successfully
#          13:10:46 - Published
# 2026-01-08 13:10:46,139 - fabric_cicd._items._lakehouse - INFO - ->Published
# [warn]   13:10:46 - The underlying legacy Microsoft Fabric Environment APIs will be deprecated by March 1, 2026.
# 2026-01-08 13:10:46,139 - fabric_cicd._items._environment - WARNING - The underlying legacy Microsoft Fabric Environment APIs will be deprecated by March 1, 2026.
# [warn]   13:10:46 - Please upgrade to the latest fabric-cicd version before March 1, 2026 to prevent broken Environment item deployments.
# 2026-01-08 13:10:46,139 - fabric_cicd._items._environment - WARNING - Please upgrade to the latest fabric-cicd version before March 1, 2026 to prevent broken Environment item deployments.
# [info]   13:10:46 - Checking Environment Publish State for ['SparkEnv']
# 2026-01-08 13:10:46,139 - fabric_cicd._items._environment - INFO - Checking Environment Publish State for ['SparkEnv']
# 2026-01-08 13:10:46,139 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# ####################################################################################################
# ########## Publishing Environments #################################################################
# ####################################################################################################
# 2026-01-08 13:10:46,748 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/environments/ HTTP/1.1" 200 357
# [info]   13:10:46 - Publishing Environment 'SparkEnv'
# 2026-01-08 13:10:46,764 - fabric_cicd.fabric_workspace - INFO - Publishing Environment 'SparkEnv'
# 2026-01-08 13:10:46,764 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:10:47,680 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "POST /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/items/05c2570e-4d79-490b-8308-db2f8ff28a0f/updateDefinition?updateMetadata=True HTTP/1.1" 202 24
# 2026-01-08 13:10:48,688 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): df-msit-scus-redirect.analysis.windows.net:443
# 2026-01-08 13:10:49,149 - urllib3.connectionpool - DEBUG - https://df-msit-scus-redirect.analysis.windows.net:443 "GET /v1/operations/c351fe0a-71b9-4b29-bd61-d2b920fdbff0 HTTP/1.1" 200 123
#          13:10:49 - Operation in progress. Checking again in 1 second (Attempt 1)...
# 2026-01-08 13:10:49,149 - fabric_cicd._common._fabric_endpoint - INFO - ->->Operation in progress. Checking again in 1 second (Attempt 1)...
# 2026-01-08 13:10:50,160 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): df-msit-scus-redirect.analysis.windows.net:443
# 2026-01-08 13:10:50,569 - urllib3.connectionpool - DEBUG - https://df-msit-scus-redirect.analysis.windows.net:443 "GET /v1/operations/c351fe0a-71b9-4b29-bd61-d2b920fdbff0 HTTP/1.1" 200 131
# 2026-01-08 13:10:50,569 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): df-msit-scus-redirect.analysis.windows.net:443
# 2026-01-08 13:10:51,082 - urllib3.connectionpool - DEBUG - https://df-msit-scus-redirect.analysis.windows.net:443 "GET /v1/operations/c351fe0a-71b9-4b29-bd61-d2b920fdbff0/result HTTP/1.1" 200 None
# 2026-01-08 13:10:51,082 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:10:52,298 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "PATCH /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/environments/05c2570e-4d79-490b-8308-db2f8ff28a0f/staging/sparkcompute?beta=False HTTP/1.1" 200 689
#          13:10:52 - Updated Spark Settings
# 2026-01-08 13:10:52,298 - fabric_cicd._items._environment - INFO - ->Updated Spark Settings
# 2026-01-08 13:10:52,298 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:10:54,873 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "POST /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/environments/05c2570e-4d79-490b-8308-db2f8ff28a0f/staging/publish?beta=False HTTP/1.1" 202 0
#          13:10:54 - Publish Submitted for Environment 'SparkEnv'
# 2026-01-08 13:10:54,873 - fabric_cicd._items._environment - INFO - ->Publish Submitted for Environment 'SparkEnv'
# 2026-01-08 13:10:54,873 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# ####################################################################################################
# ########## Publishing Spark Job Definitions ########################################################
# ####################################################################################################
# 2026-01-08 13:10:55,373 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/items HTTP/1.1" 200 497
# 2026-01-08 13:10:55,389 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:10:55,914 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/warehouses/cc88a5ac-f557-4e8d-8561-10f7df6a570e HTTP/1.1" 200 405
# 2026-01-08 13:10:55,914 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:10:56,313 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/lakehouses/704e00ae-02bc-4190-ac31-67c3e17ad6f5 HTTP/1.1" 200 428
# 2026-01-08 13:10:56,329 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:10:56,848 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/lakehouses/704e00ae-02bc-4190-ac31-67c3e17ad6f5 HTTP/1.1" 200 428
# [info]   13:10:56 - Publishing SparkJobDefinition 'StreamBronzeAndSilver'
# 2026-01-08 13:10:56,848 - fabric_cicd.fabric_workspace - INFO - Publishing SparkJobDefinition 'StreamBronzeAndSilver'
# 2026-01-08 13:10:56,848 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:10:58,214 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "POST /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/items/7282efad-47f4-4ab6-a165-1f32fc96a157/updateDefinition?updateMetadata=True HTTP/1.1" 202 24
# 2026-01-08 13:10:59,218 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): df-msit-scus-redirect.analysis.windows.net:443
# 2026-01-08 13:10:59,582 - urllib3.connectionpool - DEBUG - https://df-msit-scus-redirect.analysis.windows.net:443 "GET /v1/operations/145b36e1-5b8b-4472-940a-cb284bd07623 HTTP/1.1" 200 121
#          13:10:59 - Operation in progress. Checking again in 1 second (Attempt 1)...
# 2026-01-08 13:10:59,593 - fabric_cicd._common._fabric_endpoint - INFO - ->->Operation in progress. Checking again in 1 second (Attempt 1)...
# 2026-01-08 13:11:00,598 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): df-msit-scus-redirect.analysis.windows.net:443
# 2026-01-08 13:11:00,946 - urllib3.connectionpool - DEBUG - https://df-msit-scus-redirect.analysis.windows.net:443 "GET /v1/operations/145b36e1-5b8b-4472-940a-cb284bd07623 HTTP/1.1" 200 121
#          13:11:00 - Operation in progress. Checking again in 2 seconds (Attempt 2)...
# 2026-01-08 13:11:00,949 - fabric_cicd._common._fabric_endpoint - INFO - ->->Operation in progress. Checking again in 2 seconds (Attempt 2)...
# 2026-01-08 13:11:02,950 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): df-msit-scus-redirect.analysis.windows.net:443
# 2026-01-08 13:11:03,342 - urllib3.connectionpool - DEBUG - https://df-msit-scus-redirect.analysis.windows.net:443 "GET /v1/operations/145b36e1-5b8b-4472-940a-cb284bd07623 HTTP/1.1" 200 121
#          13:11:03 - Operation in progress. Checking again in 4 seconds (Attempt 3)...
# 2026-01-08 13:11:03,344 - fabric_cicd._common._fabric_endpoint - INFO - ->->Operation in progress. Checking again in 4 seconds (Attempt 3)...
# 2026-01-08 13:11:07,344 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): df-msit-scus-redirect.analysis.windows.net:443
# 2026-01-08 13:11:07,708 - urllib3.connectionpool - DEBUG - https://df-msit-scus-redirect.analysis.windows.net:443 "GET /v1/operations/145b36e1-5b8b-4472-940a-cb284bd07623 HTTP/1.1" 200 132
# 2026-01-08 13:11:07,710 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): df-msit-scus-redirect.analysis.windows.net:443
# 2026-01-08 13:11:08,099 - urllib3.connectionpool - DEBUG - https://df-msit-scus-redirect.analysis.windows.net:443 "GET /v1/operations/145b36e1-5b8b-4472-940a-cb284bd07623/result HTTP/1.1" 200 None
#          13:11:08 - Published
# 2026-01-08 13:11:08,107 - fabric_cicd.fabric_workspace - INFO - ->Published
# 2026-01-08 13:11:08,109 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# ####################################################################################################
# ########## Publishing Notebooks ####################################################################
# ####################################################################################################
# 2026-01-08 13:11:08,727 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/items HTTP/1.1" 200 497
# 2026-01-08 13:11:08,742 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:11:09,054 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/warehouses/cc88a5ac-f557-4e8d-8561-10f7df6a570e HTTP/1.1" 200 405
# 2026-01-08 13:11:09,054 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:11:09,664 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/lakehouses/704e00ae-02bc-4190-ac31-67c3e17ad6f5 HTTP/1.1" 200 428
# 2026-01-08 13:11:09,664 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:11:10,281 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/lakehouses/704e00ae-02bc-4190-ac31-67c3e17ad6f5 HTTP/1.1" 200 428
# 2026-01-08 13:11:10,296 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:11:10,704 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/items HTTP/1.1" 200 497
# 2026-01-08 13:11:10,711 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:11:11,012 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/warehouses/cc88a5ac-f557-4e8d-8561-10f7df6a570e HTTP/1.1" 200 405
# 2026-01-08 13:11:11,017 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:11:11,649 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/lakehouses/704e00ae-02bc-4190-ac31-67c3e17ad6f5 HTTP/1.1" 200 428
# 2026-01-08 13:11:11,649 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:11:12,029 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/lakehouses/704e00ae-02bc-4190-ac31-67c3e17ad6f5 HTTP/1.1" 200 428
# 2026-01-08 13:11:12,029 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:11:12,345 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/items HTTP/1.1" 200 497
# 2026-01-08 13:11:12,361 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:11:12,830 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/warehouses/cc88a5ac-f557-4e8d-8561-10f7df6a570e HTTP/1.1" 200 405
# 2026-01-08 13:11:12,840 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:11:13,416 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/lakehouses/704e00ae-02bc-4190-ac31-67c3e17ad6f5 HTTP/1.1" 200 428
# 2026-01-08 13:11:13,416 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:11:13,965 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/lakehouses/704e00ae-02bc-4190-ac31-67c3e17ad6f5 HTTP/1.1" 200 428
# [info]   13:11:13 - Publishing Notebook '1_ExploreData'
# 2026-01-08 13:11:13,965 - fabric_cicd.fabric_workspace - INFO - Publishing Notebook '1_ExploreData'
# 2026-01-08 13:11:13,965 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:11:14,630 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "POST /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/items/e51a908c-f903-4d57-a7bd-fcf458363e63/updateDefinition?updateMetadata=True HTTP/1.1" 202 24
# 2026-01-08 13:11:15,647 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): df-msit-scus-redirect.analysis.windows.net:443
# 2026-01-08 13:11:16,103 - urllib3.connectionpool - DEBUG - https://df-msit-scus-redirect.analysis.windows.net:443 "GET /v1/operations/dd8e4874-ae48-4b01-b64d-29b858f7d691 HTTP/1.1" 200 131
# 2026-01-08 13:11:16,109 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): df-msit-scus-redirect.analysis.windows.net:443
# 2026-01-08 13:11:16,558 - urllib3.connectionpool - DEBUG - https://df-msit-scus-redirect.analysis.windows.net:443 "GET /v1/operations/dd8e4874-ae48-4b01-b64d-29b858f7d691/result HTTP/1.1" 200 None
#          13:11:16 - Published
# 2026-01-08 13:11:16,563 - fabric_cicd.fabric_workspace - INFO - ->Published
# [info]   13:11:16 - Publishing Notebook '2_ModelData'
# 2026-01-08 13:11:16,563 - fabric_cicd.fabric_workspace - INFO - Publishing Notebook '2_ModelData'
# 2026-01-08 13:11:16,563 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:11:17,298 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "POST /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/items/beea6722-0d3a-4a28-9ae2-df9ae3f8b706/updateDefinition?updateMetadata=True HTTP/1.1" 202 24
# 2026-01-08 13:11:18,312 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): df-msit-scus-redirect.analysis.windows.net:443
# 2026-01-08 13:11:18,638 - urllib3.connectionpool - DEBUG - https://df-msit-scus-redirect.analysis.windows.net:443 "GET /v1/operations/4211c23a-8d2f-4168-ba4e-19160a572268 HTTP/1.1" 200 129
# 2026-01-08 13:11:18,638 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): df-msit-scus-redirect.analysis.windows.net:443
# 2026-01-08 13:11:19,032 - urllib3.connectionpool - DEBUG - https://df-msit-scus-redirect.analysis.windows.net:443 "GET /v1/operations/4211c23a-8d2f-4168-ba4e-19160a572268/result HTTP/1.1" 200 None
#          13:11:19 - Published
# 2026-01-08 13:11:19,032 - fabric_cicd.fabric_workspace - INFO - ->Published
# [info]   13:11:19 - Checking Environment Publish State for ['SparkEnv']
# 2026-01-08 13:11:19,040 - fabric_cicd._items._environment - INFO - Checking Environment Publish State for ['SparkEnv']
# 2026-01-08 13:11:19,040 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# ####################################################################################################
# ########## Checking Environment Publish State ######################################################
# ####################################################################################################
# 2026-01-08 13:11:20,411 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/environments/ HTTP/1.1" 200 352
#          13:11:20 - Operation in progress. Checking again in 10 seconds (Attempt 1)...
# 2026-01-08 13:11:20,411 - fabric_cicd._common._fabric_endpoint - INFO - ->->Operation in progress. Checking again in 10 seconds (Attempt 1)...
# 2026-01-08 13:11:30,418 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:11:31,132 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/environments/ HTTP/1.1" 200 352
#          13:11:31 - Operation in progress. Checking again in 20 seconds (Attempt 2)...
# 2026-01-08 13:11:31,132 - fabric_cicd._common._fabric_endpoint - INFO - ->->Operation in progress. Checking again in 20 seconds (Attempt 2)...
# 2026-01-08 13:11:51,136 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:11:51,790 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/environments/ HTTP/1.1" 200 352
#          13:11:51 - Operation in progress. Checking again in 40 seconds (Attempt 3)...
# 2026-01-08 13:11:51,790 - fabric_cicd._common._fabric_endpoint - INFO - ->->Operation in progress. Checking again in 40 seconds (Attempt 3)...
# 2026-01-08 13:12:31,795 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:12:32,490 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/environments/ HTTP/1.1" 200 352
#          13:12:32 - Operation in progress. Checking again in 80 seconds (Attempt 4)...
# 2026-01-08 13:12:32,501 - fabric_cicd._common._fabric_endpoint - INFO - ->->Operation in progress. Checking again in 80 seconds (Attempt 4)...
# 2026-01-08 13:13:52,504 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:13:53,081 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/environments/ HTTP/1.1" 200 352
#          13:13:53 - Operation in progress. Checking again in 120 seconds (Attempt 5)...
# 2026-01-08 13:13:53,083 - fabric_cicd._common._fabric_endpoint - INFO - ->->Operation in progress. Checking again in 120 seconds (Attempt 5)...
# 2026-01-08 13:15:53,085 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:15:53,887 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/environments/ HTTP/1.1" 200 352
#          13:15:53 - Operation in progress. Checking again in 120 seconds (Attempt 6)...
# 2026-01-08 13:15:53,890 - fabric_cicd._common._fabric_endpoint - INFO - ->->Operation in progress. Checking again in 120 seconds (Attempt 6)...
# 2026-01-08 13:17:53,892 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.powerbi.com:443
# 2026-01-08 13:17:54,596 - urllib3.connectionpool - DEBUG - https://api.powerbi.com:443 "GET /v1/workspaces/f863f615-5301-46e4-9654-af55769b39dd/environments/ HTTP/1.1" 200 356
#          13:17:54 - Published: ['SparkEnv']
# 2026-01-08 13:17:54,597 - fabric_cicd._items._environment - INFO - ->Published: ['SparkEnv']
# 2026-01-08 13:17:54,600 - fabric_jumpstart.core - INFO - Successfully installed 'analytics-roadshow-lab'
