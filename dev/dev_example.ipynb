# %%
import importlib
import fabric_jumpstart as jumpstart

# Reload all modules including new ones
importlib.reload(jumpstart.logger)
importlib.reload(jumpstart.registry)
importlib.reload(jumpstart.workspace_manager)
importlib.reload(jumpstart.installer)
importlib.reload(jumpstart.ui)
importlib.reload(jumpstart.core)
jumpstart.list(show_unlisted=True)
# Out:
# <style>/* ============================================================================
#    Fabric Jumpstart UI Styles
#    Unified CSS for list view and install status displays
#    ============================================================================ */
#
# /* Global styles */
# * {
#     box-sizing: border-box;
# }
#
# /* ============================================================================
#    Jumpstart List View
#    ============================================================================ */
#
# .jumpstart-container {
#     font-family: 'Segoe UI', -apple-system, BlinkMacSystemFont, 'Roboto', 'Helvetica Neue', sans-serif;
#     max-height: 980px;
#     overflow: auto;
#     overscroll-behavior: contain;
#     margin: 0 auto;
#     padding: 40px 20px;
#     background: #fafafa;
# }
#
# .jumpstart-header {
#     margin-bottom: 40px;
# }
#
# .jumpstart-label {
#     color: #117865;
#     font-size: 16px;
#     font-weight: 600;
#     text-transform: uppercase;
#     letter-spacing: 2.25px;
#     margin-bottom: 8px;
# }
#
# .jumpstart-header h1 {
#     color: #1f1f1f;
#     font-size: 32px;
#     margin: 0 0 12px 0;
#     font-weight: 700;
#     line-height: 1.2;
# }
#
# .jumpstart-header p {
#     color: #605e5c;
#     font-size: 18px;
#     font-weight: 350;
#     margin: 0;
#     line-height: 1.5;
# }
#
# /* Controls and filters */
# .controls-stack {
#     display: flex;
#     flex-direction: column;
#     gap: 10px;
#     margin-bottom: 28px;
#     position: relative;
#     z-index: 50;
# }
#
# .controls-row {
#     display: flex;
#     flex-wrap: wrap;
#     align-items: center;
#     gap: 12px;
# }
#
# .filters-bar {
#     display: flex;
#     align-items: stretch;
#     justify-content: flex-start;
#     gap: 10px;
#     flex-wrap: wrap;
# }
#
# .filters-bar-row {
#     display: flex;
#     align-items: center;
#     flex-wrap: wrap;
#     gap: 10px;
#     justify-content: flex-start;
#     position: relative;
#     z-index: 50;
#     margin-bottom: 30px;
# }
#
# .filters-active {
#     display: flex;
#     flex-wrap: wrap;
#     gap: 8px;
#     min-height: 34px;
#     flex: 0 1 auto;
#     min-width: 0;
# }
#
# .group-by-chip {
#     display: inline-flex;
#     align-items: center;
#     gap: 10px;
#     padding: 6px 10px;
#     border: 1px solid #edebe9;
#     border-radius: 6px;
#     background: #ffffff;
#     box-shadow: 0 1px 2px rgba(0,0,0,0.06);
#     flex: 0 0 auto;
# }
#
# .group-by-chip .filter-chip-label {
#     margin-right: 2px;
# }
#
# .add-filter-wrapper {
#     position: relative;
#     display: inline-flex;
#     align-items: center;
#     z-index: 60;
#     flex: 0 0 auto;
#     pointer-events: auto;
# }
#
# .add-filter-btn {
#     background: transparent;
#     border: 1px dashed #c8c6c4;
#     color: #323130;
#     padding: 6px 12px;
#     border-radius: 6px;
#     font-weight: 600;
#     cursor: pointer;
#     transition: border-color 0.2s, background 0.2s;
#     height: 100%;
#     pointer-events: auto;
#     position: relative;
#     z-index: 70;
# }
#
# .add-filter-btn:hover {
#     border-color: #8a8886;
#     background: #ffffff;
# }
#
# .add-filter-btn:disabled {
#     opacity: 0.5;
#     cursor: not-allowed;
# }
#
# .filter-menu {
#     position: absolute;
#     right: 0;
#     top: calc(100% + 6px);
#     background: #ffffff;
#     border: 1px solid #edebe9;
#     border-radius: 6px;
#     box-shadow: 0 3px 12px rgba(0,0,0,0.12);
#     padding: 8px;
#     display: none;
#     z-index: 20;
#     min-width: 160px;
# }
#
# .filter-menu-btn {
#     width: 100%;
#     background: transparent;
#     border: none;
#     text-align: left;
#     padding: 8px 10px;
#     border-radius: 4px;
#     cursor: pointer;
#     font-weight: 600;
#     color: #323130;
# }
#
# .filter-menu-btn:hover {
#     background: #f3f2f1;
# }
#
# .filter-menu-empty {
#     padding: 8px 10px;
#     font-size: 12px;
#     color: #8a8886;
#     font-weight: 600;
# }
#
# .filter-chip {
#     display: inline-flex;
#     align-items: center;
#     gap: 12px;
#     padding: 6px 8px;
#     border: 1px solid #edebe9;
#     border-radius: 4px;
#     background: #ffffff;
#     box-shadow: 0 1px 2px rgba(0,0,0,0.06);
# }
#
# .filter-chip-label {
#     font-size: 12px;
#     font-weight: 600;
#     color: #323130;
# }
#
# .filter-select {
#     border: 1px solid #edebe9;
#     border-radius: 6px;
#     padding: 4px 8px;
#     font-size: 12px;
#     background: #ffffff;
#     color: #323130;
#     transition: border-color 0.2s, background 0.2s, color 0.2s;
# }
#
# .filter-select:hover,
# .filter-select:focus {
#     border-color: #117865;
#     background: #ffffff;
#     color: #323130;
#     outline: none;
# }
#
# .filter-select option:hover {
#     background: #117865;
#     color: #ffffff;
# }
#
# .filter-chip-remove {
#     background: transparent;
#     border: none;
#     font-size: 14px;
#     cursor: pointer;
#     color: #605e5c;
#     padding: 0 4px;
# }
#
# .filter-chip-remove:hover {
#     color: #323130;
# }
#
# /* Toggle button group */
# .filters-row {
#     display: inline-flex;
#     align-items: center;
#     gap: 12px;
#     margin-bottom: 20px;
#     flex-wrap: wrap;
#     padding: 6px 8px;
#     border: 1px solid #edebe9;
#     border-radius: 4px;
#     background: #ffffff;
#     box-shadow: 0 1px 2px rgba(0,0,0,0.06);
#     width: fit-content;
# }
#
# .group-by-label {
#     font-size: 12px;
#     font-weight: 600;
#     color: #323130;
#     line-height: 1.4;
# }
#
# .toggle-group {
#     display: inline-flex;
#     border: 1px solid #d2d0ce;
#     border-radius: 6px;
#     overflow: hidden;
#     height: 32px;
# }
#
# .toggle-group.compact {
#     border-color: #edebe9;
#     border-radius: 6px;
# }
#
# .toggle-group button {
#     background: #fafafa;
#     color: #323130;
#     border: none;
#     padding: 6px 16px;
#     font-size: 13px;
#     font-weight: 600;
#     cursor: pointer;
#     transition: all 0.2s;
#     border-right: 1px solid #d2d0ce;
#     height: 100%;
# }
#
# .toggle-group.compact button {
#     padding: 6px 12px;
#     min-width: 0;
# }
#
# .toggle-group button:last-child {
#     border-right: none;
# }
#
# .toggle-group button.active {
#     background: linear-gradient(135deg, #117865 0%, #0C695A 100%);
#     color: white;
# }
#
# .toggle-group button:hover:not(.active) {
#     background: #ffffff;
# }
#
# /* Tag filter pills */
# .tag-filters {
#     display: flex;
#     flex-wrap: wrap;
#     gap: 10px;
#     margin: 0;
# }
#
# .tag-filter-row {
#     margin-bottom: 40px;
# }
#
# .tag-filter-btn {
#     background: transparent;
#     color: #323130;
#     border: 1px solid #d2d0ce;
#     padding: 6px 18px;
#     border-radius: 4px;
#     font-size: 13px;
#     font-weight: 500;
#     cursor: pointer;
#     transition: all 0.2s;
# }
#
# .tag-filter-btn:hover {
#     background: #ffffff;
#     border-color: #8a8886;
# }
#
# .tag-filter-btn.active {
#     background: linear-gradient(135deg, #117865 0%, #0C695A 100%);
#     color: white;
#     border-color: transparent;
# }
#
# /* Metadata pills */
# .type-pill {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 3px 8px;
#     border-radius: 999px;
#     font-size: 12px;
#     font-weight: 600;
#     background: #e6f4ef;
#     color: #0C695A;
#     border: 1px solid #b8e0d2;
#     width: fit-content;
#     margin: 0;
#     letter-spacing: 0.1px;
# }
#
# .duration-pill {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 3px 8px;
#     border-radius: 999px;
#     font-size: 12px;
#     font-weight: 600;
#     background: #eef6ff;
#     color: #0f4f8f;
#     border: 1px solid #d5e8ff;
#     width: fit-content;
#     margin: 0;
#     letter-spacing: 0.1px;
# }
#
# .deploy-pill {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 3px 8px;
#     border-radius: 999px;
#     font-size: 12px;
#     font-weight: 600;
#     background: #f7f0e6;
#     color: #7b4b06;
#     border: 1px solid #e2c79b;
#     width: fit-content;
#     margin: 0;
#     letter-spacing: 0.1px;
# }
#
# .meta-pills {
#     display: flex !important;
#     align-items: center;
#     flex-wrap: wrap;
#     gap: 8px;
#     margin-bottom: 12px;
#     min-height: 24px;
# }
#
# /* Category sections */
# .category-section {
#     margin-bottom: 56px;
# }
#
# .category-section.hidden {
#     display: none;
# }
#
# .category-label {
#     color: #117865;
#     font-size: 16px;
#     font-weight: 600;
#     text-transform: uppercase;
#     letter-spacing: 2.25px;
#     margin-bottom: 4px;
# }
#
# .category-title {
#     color: #1f1f1f;
#     font-size: 24px;
#     font-weight: 700;
#     margin: 0 0 30px 0;
#     line-height: 1.2;
# }
#
# /* Jumpstart cards */
# .ju

# %%
jumpstart.install("analytics-roadshow-lab", workspace_id="")
# Out:
# <style>/* ============================================================================
#    Fabric Jumpstart UI Styles
#    Unified CSS for list view and install status displays
#    ============================================================================ */
#
# /* Global styles */
# * {
#     box-sizing: border-box;
# }
#
# /* ============================================================================
#    Jumpstart List View
#    ============================================================================ */
#
# .jumpstart-container {
#     font-family: 'Segoe UI', -apple-system, BlinkMacSystemFont, 'Roboto', 'Helvetica Neue', sans-serif;
#     max-height: 980px;
#     overflow: auto;
#     overscroll-behavior: contain;
#     margin: 0 auto;
#     padding: 40px 20px;
#     background: #fafafa;
# }
#
# .jumpstart-header {
#     margin-bottom: 40px;
# }
#
# .jumpstart-label {
#     color: #117865;
#     font-size: 16px;
#     font-weight: 600;
#     text-transform: uppercase;
#     letter-spacing: 2.25px;
#     margin-bottom: 8px;
# }
#
# .jumpstart-header h1 {
#     color: #1f1f1f;
#     font-size: 32px;
#     margin: 0 0 12px 0;
#     font-weight: 700;
#     line-height: 1.2;
# }
#
# .jumpstart-header p {
#     color: #605e5c;
#     font-size: 18px;
#     font-weight: 350;
#     margin: 0;
#     line-height: 1.5;
# }
#
# /* Controls and filters */
# .controls-stack {
#     display: flex;
#     flex-direction: column;
#     gap: 10px;
#     margin-bottom: 28px;
#     position: relative;
#     z-index: 50;
# }
#
# .controls-row {
#     display: flex;
#     flex-wrap: wrap;
#     align-items: center;
#     gap: 12px;
# }
#
# .filters-bar {
#     display: flex;
#     align-items: stretch;
#     justify-content: flex-start;
#     gap: 10px;
#     flex-wrap: wrap;
# }
#
# .filters-bar-row {
#     display: flex;
#     align-items: center;
#     flex-wrap: wrap;
#     gap: 10px;
#     justify-content: flex-start;
#     position: relative;
#     z-index: 50;
#     margin-bottom: 30px;
# }
#
# .filters-active {
#     display: flex;
#     flex-wrap: wrap;
#     gap: 8px;
#     min-height: 34px;
#     flex: 0 1 auto;
#     min-width: 0;
# }
#
# .group-by-chip {
#     display: inline-flex;
#     align-items: center;
#     gap: 10px;
#     padding: 6px 10px;
#     border: 1px solid #edebe9;
#     border-radius: 6px;
#     background: #ffffff;
#     box-shadow: 0 1px 2px rgba(0,0,0,0.06);
#     flex: 0 0 auto;
# }
#
# .group-by-chip .filter-chip-label {
#     margin-right: 2px;
# }
#
# .add-filter-wrapper {
#     position: relative;
#     display: inline-flex;
#     align-items: center;
#     z-index: 60;
#     flex: 0 0 auto;
#     pointer-events: auto;
# }
#
# .add-filter-btn {
#     background: transparent;
#     border: 1px dashed #c8c6c4;
#     color: #323130;
#     padding: 6px 12px;
#     border-radius: 6px;
#     font-weight: 600;
#     cursor: pointer;
#     transition: border-color 0.2s, background 0.2s;
#     height: 100%;
#     pointer-events: auto;
#     position: relative;
#     z-index: 70;
# }
#
# .add-filter-btn:hover {
#     border-color: #8a8886;
#     background: #ffffff;
# }
#
# .add-filter-btn:disabled {
#     opacity: 0.5;
#     cursor: not-allowed;
# }
#
# .filter-menu {
#     position: absolute;
#     right: 0;
#     top: calc(100% + 6px);
#     background: #ffffff;
#     border: 1px solid #edebe9;
#     border-radius: 6px;
#     box-shadow: 0 3px 12px rgba(0,0,0,0.12);
#     padding: 8px;
#     display: none;
#     z-index: 20;
#     min-width: 160px;
# }
#
# .filter-menu-btn {
#     width: 100%;
#     background: transparent;
#     border: none;
#     text-align: left;
#     padding: 8px 10px;
#     border-radius: 4px;
#     cursor: pointer;
#     font-weight: 600;
#     color: #323130;
# }
#
# .filter-menu-btn:hover {
#     background: #f3f2f1;
# }
#
# .filter-menu-empty {
#     padding: 8px 10px;
#     font-size: 12px;
#     color: #8a8886;
#     font-weight: 600;
# }
#
# .filter-chip {
#     display: inline-flex;
#     align-items: center;
#     gap: 12px;
#     padding: 6px 8px;
#     border: 1px solid #edebe9;
#     border-radius: 4px;
#     background: #ffffff;
#     box-shadow: 0 1px 2px rgba(0,0,0,0.06);
# }
#
# .filter-chip-label {
#     font-size: 12px;
#     font-weight: 600;
#     color: #323130;
# }
#
# .filter-select {
#     border: 1px solid #edebe9;
#     border-radius: 6px;
#     padding: 4px 8px;
#     font-size: 12px;
#     background: #ffffff;
#     color: #323130;
#     transition: border-color 0.2s, background 0.2s, color 0.2s;
# }
#
# .filter-select:hover,
# .filter-select:focus {
#     border-color: #117865;
#     background: #ffffff;
#     color: #323130;
#     outline: none;
# }
#
# .filter-select option:hover {
#     background: #117865;
#     color: #ffffff;
# }
#
# .filter-chip-remove {
#     background: transparent;
#     border: none;
#     font-size: 14px;
#     cursor: pointer;
#     color: #605e5c;
#     padding: 0 4px;
# }
#
# .filter-chip-remove:hover {
#     color: #323130;
# }
#
# /* Toggle button group */
# .filters-row {
#     display: inline-flex;
#     align-items: center;
#     gap: 12px;
#     margin-bottom: 20px;
#     flex-wrap: wrap;
#     padding: 6px 8px;
#     border: 1px solid #edebe9;
#     border-radius: 4px;
#     background: #ffffff;
#     box-shadow: 0 1px 2px rgba(0,0,0,0.06);
#     width: fit-content;
# }
#
# .group-by-label {
#     font-size: 12px;
#     font-weight: 600;
#     color: #323130;
#     line-height: 1.4;
# }
#
# .toggle-group {
#     display: inline-flex;
#     border: 1px solid #d2d0ce;
#     border-radius: 6px;
#     overflow: hidden;
#     height: 32px;
# }
#
# .toggle-group.compact {
#     border-color: #edebe9;
#     border-radius: 6px;
# }
#
# .toggle-group button {
#     background: #fafafa;
#     color: #323130;
#     border: none;
#     padding: 6px 16px;
#     font-size: 13px;
#     font-weight: 600;
#     cursor: pointer;
#     transition: all 0.2s;
#     border-right: 1px solid #d2d0ce;
#     height: 100%;
# }
#
# .toggle-group.compact button {
#     padding: 6px 12px;
#     min-width: 0;
# }
#
# .toggle-group button:last-child {
#     border-right: none;
# }
#
# .toggle-group button.active {
#     background: linear-gradient(135deg, #117865 0%, #0C695A 100%);
#     color: white;
# }
#
# .toggle-group button:hover:not(.active) {
#     background: #ffffff;
# }
#
# /* Tag filter pills */
# .tag-filters {
#     display: flex;
#     flex-wrap: wrap;
#     gap: 10px;
#     margin: 0;
# }
#
# .tag-filter-row {
#     margin-bottom: 40px;
# }
#
# .tag-filter-btn {
#     background: transparent;
#     color: #323130;
#     border: 1px solid #d2d0ce;
#     padding: 6px 18px;
#     border-radius: 4px;
#     font-size: 13px;
#     font-weight: 500;
#     cursor: pointer;
#     transition: all 0.2s;
# }
#
# .tag-filter-btn:hover {
#     background: #ffffff;
#     border-color: #8a8886;
# }
#
# .tag-filter-btn.active {
#     background: linear-gradient(135deg, #117865 0%, #0C695A 100%);
#     color: white;
#     border-color: transparent;
# }
#
# /* Metadata pills */
# .type-pill {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 3px 8px;
#     border-radius: 999px;
#     font-size: 12px;
#     font-weight: 600;
#     background: #e6f4ef;
#     color: #0C695A;
#     border: 1px solid #b8e0d2;
#     width: fit-content;
#     margin: 0;
#     letter-spacing: 0.1px;
# }
#
# .duration-pill {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 3px 8px;
#     border-radius: 999px;
#     font-size: 12px;
#     font-weight: 600;
#     background: #eef6ff;
#     color: #0f4f8f;
#     border: 1px solid #d5e8ff;
#     width: fit-content;
#     margin: 0;
#     letter-spacing: 0.1px;
# }
#
# .deploy-pill {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 3px 8px;
#     border-radius: 999px;
#     font-size: 12px;
#     font-weight: 600;
#     background: #f7f0e6;
#     color: #7b4b06;
#     border: 1px solid #e2c79b;
#     width: fit-content;
#     margin: 0;
#     letter-spacing: 0.1px;
# }
#
# .meta-pills {
#     display: flex !important;
#     align-items: center;
#     flex-wrap: wrap;
#     gap: 8px;
#     margin-bottom: 12px;
#     min-height: 24px;
# }
#
# /* Category sections */
# .category-section {
#     margin-bottom: 56px;
# }
#
# .category-section.hidden {
#     display: none;
# }
#
# .category-label {
#     color: #117865;
#     font-size: 16px;
#     font-weight: 600;
#     text-transform: uppercase;
#     letter-spacing: 2.25px;
#     margin-bottom: 4px;
# }
#
# .category-title {
#     color: #1f1f1f;
#     font-size: 24px;
#     font-weight: 700;
#     margin: 0 0 30px 0;
#     line-height: 1.2;
# }
#
# /* Jumpstart cards */
# .ju
# ---------------------------------------------------------------------------
# InputError                                Traceback (most recent call last)
# File ~\source\fabric-jumpstart\src\fabric_jumpstart\core.py:261, in jumpstart.install(self, name, workspace_id, **kwargs)
#     260 # Phase 2: Check for conflicts
# --> 261 planned_items_base, existing_items, conflicts, had_conflicts = installer.check_conflicts()
#     263 # Phase 3: Resolve conflicts
#
# File ~\source\fabric-jumpstart\src\fabric_jumpstart\installer.py:161, in JumpstartInstaller.check_conflicts(self)
#     159     raise RuntimeError("workspace_manager must be initialized before checking conflicts")
# --> 161 existing_items = self.workspace_manager.get_existing_items()
#     162 planned_items_base = self.workspace_manager.collect_planned_items()
#
# File ~\source\fabric-jumpstart\src\fabric_jumpstart\workspace_manager.py:57, in WorkspaceManager.get_existing_items(self)
#      55 from fabric_cicd.constants import DEFAULT_API_ROOT_URL
# ---> 57 workspace = self.get_fabric_workspace()
#      58 next_url = f"{DEFAULT_API_ROOT_URL}/v1/workspaces/{workspace.workspace_id}/items"
#
# File ~\source\fabric-jumpstart\src\fabric_jumpstart\workspace_manager.py:38, in WorkspaceManager.get_fabric_workspace(self)
#      37 if self._fabric_workspace is None:
# ---> 38     self._fabric_workspace = FabricWorkspace(
#      39         workspace_id=self.workspace_id,
#      40         repository_directory=str(self.workspace_path),
#      41         item_type_in_scope=self.items_in_scope
#      42     )
#      43 return self._fabric_workspace
#
# File c:\Users\milescole\source\fabric-jumpstart\src\fabric_jumpstart\.venv\Lib\site-packages\fabric_cicd\fabric_workspace.py:122, in FabricWorkspace.__init__(self, repository_directory, item_type_in_scope, environment, workspace_id, workspace_name, token_credential, **kwargs)
#     121     msg = "Either workspace_name or workspace_id must be specified."
# --> 122     raise InputError(msg, logger)
#     124 # Validate and set class variables
#
# InputError: Either workspace_name or workspace_id must be specified.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 jumpstart.install("analytics-roadshow-lab", workspace_id="")
#
# File ~\source\fabric-jumpstart\src\fabric_jumpstart\core.py:375, in jumpstart.install(self, name, workspace_id, **kwargs)
#     372 _update_live(status_label='error', entry=config.get('entry_point'), err=error_text)
#     374 if live_rendering:
# --> 375     raise RuntimeError(error_text)
#     377 try:
#     378     from IPython.display import HTML, display
#
# RuntimeError: Either workspace_name or workspace_id must be specified.
