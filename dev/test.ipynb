# %%
import importlib
import fabric_jumpstart as jumpstart
importlib.reload(jumpstart.ui)
importlib.reload(jumpstart.core)
importlib.reload(jumpstart.utils)
importlib.reload(jumpstart.response)
importlib.reload(jumpstart)
jumpstart.ui.reload_assets()

# %%
jumpstart.install("analytics-lab", workspace_id="1e5cfd3c-ef5a-4cc1-8e22-2b3ed092c779")
# Out:
# <style>.install-status-card {
#     border: 1px solid #edebe9;
#     border-radius: 10px;
#     padding: 16px;
#     margin: 12px 0;
#     background: #ffffff;
#     box-shadow: 0 8px 24px rgba(0, 0, 0, .12);
#     font-family: "Segoe UI", Helvetica, Arial, sans-serif;
#     color: #1f1f1f;
#     position: relative;
#     overflow: hidden;
# }
#
# .install-status-card.success::before {
#     content: "";
#     position: absolute;
#     inset: -30% -10%;
#     background: radial-gradient(circle at 40% 30%, rgba(17, 120, 101, 0.02), transparent 55%), radial-gradient(circle at 80% 20%, rgba(15, 79, 143, 0.02), transparent 45%);
#     z-index: 0;
# }
#
# .install-status-card.error::before {
#     content: "";
#     position: absolute;
#     inset: -40% -20%;
#     background: radial-gradient(circle at 30% 30%, rgba(164, 38, 44, 0.08), transparent 45%), radial-gradient(circle at 80% 20%, rgba(255, 141, 141, 0.08), transparent 35%);
#     z-index: 0;
# }
#
# .install-status-card>* {
#     position: relative;
#     z-index: 1;
# }
#
# .install-hero {
#     display: flex;
#     align-items: center;
#     justify-content: space-between;
#     gap: 16px;
#     padding: 14px 16px;
#     border-radius: 10px;
#     margin-bottom: 12px;
#     box-shadow: 0 4px 14px rgba(0, 0, 0, 0.08);
# }
#
# .install-hero.success {
#     background: #f6fbf9;
#     color: #0f5246;
#     border: 1px solid #d5ebe2;
# }
#
# .install-hero.success .hero-kicker {
#     color: #0f5246;
#     opacity: 0.8;
# }
#
# .install-hero.success .hero-meta {
#     color: #0f5246
# }
#
# .install-cta {
#     border: 1px solid #0c695a;
#     background: linear-gradient(135deg, #0f9d8c, #0c695a);
#     color: #ffffff !important;
# }
#
# .install-hero.error {
#     background: linear-gradient(135deg, #d64545, #a4262c);
#     color: #ffffff;
# }
#
# .hero-icon {
#     font-size: 28px;
#     line-height: 1;
#     filter: drop-shadow(0 2px 4px rgba(0, 0, 0, 0.18));
# }
#
# .hero-text {
#     flex: 1;
#     min-width: 0;
# }
#
# .hero-kicker {
#     text-transform: uppercase;
#     letter-spacing: 0.8px;
#     font-size: 11px;
#     font-weight: 700;
#     opacity: 0.9;
# }
#
# .hero-title {
#     font-size: 18px;
#     font-weight: 800;
#     margin: 2px 0;
# }
#
# .hero-title.category-title {
#     color: #1f1f1f;
#     font-size: 24px;
#     font-weight: 700;
# }
#
# .hero-kicker.category-label {
#     color: #117865;
#     font-size: 16px;
#     text-transform: uppercase;
#     letter-spacing: 2.25px;
#     font-weight: 600;
#     opacity: 1;
# }
#
# .hero-sub {
#     color: #1f1f1f;
# }
#
# .hero-meta {
#     color: #1f1f1f;
# }
#
# .hero-sub {
#     font-size: 13px;
#     opacity: 0.9;
# }
#
# .hero-meta {
#     margin-top: 4px;
#     font-size: 12px;
#     opacity: 0.9;
# }
#
# .hero-cta {
#     display: flex;
#     align-items: center;
#     gap: 8px;
#     flex-wrap: wrap;
#     justify-content: flex-end;
# }
#
# .install-cta {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 8px 12px;
#     border-radius: 8px;
#     background: linear-gradient(135deg, #0f9d8c, #0c695a);
#     color: #ffffff !important;
#     font-weight: 700;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.16);
#     text-decoration: none;
#     border: 1px solid #0c695a;
# }
#
# .install-cta:hover {
#     transform: translateY(-1px);
#     text-decoration: none;
#     filter: brightness(1.03);
# }
#
# .install-cta.secondary {
#     background: #f7fbf9;
#     color: #0c695a !important;
#     border: 1px solid #b8dcd0;
#     box-shadow: 0 2px 6px rgba(0, 0, 0, 0.06);
# }
#
# .install-cta.secondary:hover {
#     filter: none;
#     transform: translateY(-1px);
#     background: #eef7f2;
# }
#
# .install-cta svg {
#     width: 14px;
#     height: 14px;
# }
#
# .install-hero.success .hero-icon {
#     animation: pop 0.6s ease;
# }
#
# @keyframes pop {
#     0% {
#         transform: scale(0.8);
#     }
#
#     60% {
#         transform: scale(1.08);
#     }
#
#     100% {
#         transform: scale(1);
#     }
# }
#
# .install-status-header {
#     display: flex;
#     align-items: center;
#     justify-content: space-between;
#     gap: 12px;
#     margin-bottom: 12px;
#     flex-wrap: wrap;
# }
#
# .install-status-header {
#     display: flex;
#     align-items: center;
#     justify-content: space-between;
#     gap: 12px;
#     margin-bottom: 16px;
#     flex-wrap: wrap;
# }
#
# .install-status-title {
#     font-size: 18px;
#     font-weight: 700;
#     margin: 0;
# }
#
# .install-status-subtitle {
#     font-size: 13px;
#     color: #605e5c;
#     margin: 0;
# }
#
# .install-status-pill {
#     display: inline-flex;
#     align-items: center;
#     gap: 8px;
#     padding: 6px 10px;
#     border-radius: 999px;
#     font-size: 12px;
#     font-weight: 700;
#     letter-spacing: 0.2px;
#     text-transform: uppercase;
#     box-shadow: 0 6px 14px rgba(0, 0, 0, 0.08);
# }
#
# .install-status-pill.success {
#     background: #e6f4ef;
#     color: #0C695A;
#     border: 1px solid #b8e0d2;
# }
#
# .install-status-pill.info {
#     background: #eef6ff;
#     color: #0f4f8f;
#     border: 1px solid #d5e8ff;
# }
#
# .install-status-pill.error {
#     background: #fde7e9;
#     color: #a4262c;
#     border: 1px solid #f4afb4;
# }
#
# .install-status-pill.installing {
#     gap: 6px;
# }
#
# .install-status-pill.installing .pill-icon {
#     font-weight: 700;
#     line-height: 1;
# }
#
# .install-status-pill.installing .pill-label {
#     font-weight: 700;
#     letter-spacing: 0.2px;
# }
#
# .install-status-pill.installing .pill-dots {
#     display: inline-flex;
#     align-items: center;
#     gap: 3px;
# }
#
# .install-status-pill.installing .pill-dot {
#     width: 6px;
#     height: 6px;
#     border-radius: 999px;
#     background: currentColor;
#     opacity: 0.35;
#     animation: install-dots 1.1s infinite ease-in-out;
# }
#
# .install-status-pill.installing .pill-dot:nth-child(2) {
#     animation-delay: 0.12s;
# }
#
# .install-status-pill.installing .pill-dot:nth-child(3) {
#     animation-delay: 0.24s;
# }
#
# @keyframes install-dots {
#     0%, 80%, 100% {
#         transform: scale(0.65);
#         opacity: 0.35;
#     }
#     40% {
#         transform: scale(1.15);
#         opacity: 1;
#     }
# }
#
# .install-status-grid {
#     display: grid;
#     grid-template-columns: repeat(auto-fit, minmax(220px, 1fr));
#     gap: 12px;
#     margin-top: 12px;
# }
#
# .install-status-item {
#     border: 1px solid #f3f2f1;
#     border-radius: 6px;
#     padding: 10px 12px;
#     background: #faf9f8;
# }
#
# .install-status-label {
#     font-size: 12px;
#     color: #1f1f1f;
#     margin-bottom: 4px;
#     font-weight: 600;
# }
#
# .install-status-value {
#     font-size: 14px;
#     font-weight: 600;
#     word-break: break-word;
#     color: #1f1f1f;
# }
#
# .install-status-value a {
#     color: #0f4f8f;
#     text-decoration: none;
# }
#
# .install-status-value a:hover {
#     text-decoration: underline;
# }
#
# .install-status-link {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 6px 10px;
#     border-radius: 6px;
#     background: linear-gradient(135deg, #117865 0%, #0C695A 100%);
#     color: #ffffff !important;
#     font-weight: 500;
#     box-shadow: 0 1px 2px rgba(0, 0, 0, 0.12);
# }
#
# .install-status-link:hover {
#     text-decoration: none;
#     filter: brightness(1.05);
# }
#
# .install-status-link svg {
#     width: 14px;
#     height: 14px;
# }
#
# .install-status-error {
#     margin-top: 12px;
#     padding: 10px 12px;
#     border-radius: 6px;
#     border: 1px solid #f4afb4;
#     background: #fde7e9;
#     color: #a4262c;
#     font-size: 13px;
#     word-break: break-word;
# }
#
# .install-status-section {
#     margin-top: 12px;
# }
#
# .install-status-section-title {
#     font-size: 14px;
#     font-weight: 600;
#     color: #323130;
#     letter-spacing: 0.1px;
#     margin: 0 0 8px 0;
# }
#
# /* Jumpstart-style install code blocks with copy button */
# .jumpstart-install {
#     font-family: 'Consolas', 'Courier New', monospace;
#     font-size: 13px;
#     padding: 12px 16px;
#     background: #f3f2f1;
#     border-radius: 2px;
#     border-left: 3px solid var(--accent-secondary, #0C695A);
#     cursor: pointer;
#     transition: background 0.2s;
#     position: relative;
#     display: block;
#     margin: 8px 0;
# }
#
# .jumpstart-install:hover {
#     background: #edebe9;
# }
#
# .jumpstart-install:hover .copy-btn {
#     opacity: 1;
# }
#
# .jumpstart-install code {
#     color: var(--accent-secondary, #0C695A);
#     background: transparent;
#     font-family: inherit;
# }
#
# .jumpstart-install .copy-btn {
#     position: absolute;
#     right: 8px;
#     top: 50%;
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\source\fabric-jumpstart\src\fabric_jumpstart\core.py:309, in jumpstart.install(self, name, workspace_id, **kwargs)
#     308     # Raise error to mark cell as failed
# --> 309     raise RuntimeError(f"Conflicting items detected: {', '.join(remaining_conflicts)}")
#     311 # Phase 4: Apply prefix to files
#
# RuntimeError: Conflicting items detected: 1_ExploreData.Notebook, SalesAndLogisticsLH.Lakehouse
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 jumpstart.install("analytics-lab", workspace_id="1e5cfd3c-ef5a-4cc1-8e22-2b3ed092c779")
#
# File ~\source\fabric-jumpstart\src\fabric_jumpstart\core.py:356, in jumpstart.install(self, name, workspace_id, **kwargs)
#     354 # Don't overwrite conflict UI if it's already been rendered
#     355 if conflict_already_rendered:
# --> 356     raise RuntimeError(error_text)
#     358 try:
#     359     for line in traceback.format_exception(e):
#
# RuntimeError: Conflicting items detected: 1_ExploreData.Notebook, SalesAndLogisticsLH.Lakehouse

# %%
import fabric_jumpstart as jumpstart
jumpstart.list()
# Out:
# <style>* {
#     box-sizing: border-box;
# }
# .jumpstart-container {
#     font-family: 'Segoe UI', -apple-system, BlinkMacSystemFont, 'Roboto', 'Helvetica Neue', sans-serif;
#     max-height: 1200px;
#     overflow: auto;
#     overscroll-behavior: contain;
#     margin: 0 auto;
#     padding: 40px 20px;
#     background: #fafafa;
# }
# .jumpstart-header {
#     margin-bottom: 40px;
# }
# .jumpstart-label {
#     color: #117865;
#     font-size: 16px;
#     font-weight: 600;
#     text-transform: uppercase;
#     letter-spacing: 2.25px;
#     margin-bottom: 8px;
# }
# .jumpstart-header h1 {
#     color: #1f1f1f;
#     font-size: 32px;
#     margin: 0 0 12px 0;
#     font-weight: 700;
#     line-height: 1.2;
# }
# .jumpstart-header p {
#     color: #605e5c;
#     font-size: 18px;
#     font-weight: 350;
#     margin: 0;
#     line-height: 1.5;
# }
#
# .controls-stack {
#     display: flex;
#     flex-direction: column;
#     gap: 10px;
#     margin-bottom: 28px;
#     position: relative;
#     z-index: 50;
# }
# .controls-row {
#     display: flex;
#     flex-wrap: wrap;
#     align-items: center;
#     gap: 12px;
# }
# .filters-bar {
#     display: flex;
#     align-items: stretch;
#     justify-content: flex-start;
#     gap: 10px;
#     flex-wrap: wrap;
# .filters-bar-row {
#     display: flex;
#     align-items: flex-start;
#     gap: 10px;
#     flex-wrap: wrap;
#     margin-bottom: 30px;
# }
# }
# .filters-bar-row {
#     display: flex;
#     align-items: center;
#     flex-wrap: wrap;
#     gap: 10px;
#     justify-content: flex-start;
#     position: relative;
#     z-index: 50;
#     margin-bottom: 30px;
# }
# .filters-active {
#     display: flex;
#     flex-wrap: wrap;
#     gap: 8px;
#     min-height: 34px;
#     flex: 0 1 auto;
#     min-width: 0;
# }
# .group-by-chip {
#     display: inline-flex;
#     align-items: center;
#     gap: 10px;
#     padding: 6px 10px;
#     border: 1px solid #edebe9;
#     border-radius: 6px;
#     background: #ffffff;
#     box-shadow: 0 1px 2px rgba(0,0,0,0.06);
#     flex: 0 0 auto;
# }
# .group-by-chip .filter-chip-label {
#     margin-right: 2px;
# }
# .add-filter-wrapper {
#     position: relative;
#     display: inline-flex;
#     align-items: center;
#     z-index: 60;
#     flex: 0 0 auto;
#     pointer-events: auto;
# }
# .add-filter-btn {
#     background: transparent;
#     border: 1px dashed #c8c6c4;
#     color: #323130;
#     padding: 6px 12px;
#     border-radius: 6px;
#     font-weight: 600;
#     cursor: pointer;
#     transition: border-color 0.2s, background 0.2s;
#     height: 100%;
#     pointer-events: auto;
#     position: relative;
#     z-index: 70;
# }
# .add-filter-btn:hover {
#     border-color: #8a8886;
#     background: #ffffff;
# }
# .add-filter-btn:disabled {
#     opacity: 0.5;
#     cursor: not-allowed;
# }
# .filter-menu {
#     position: absolute;
#     right: 0;
#     top: calc(100% + 6px);
#     background: #ffffff;
#     border: 1px solid #edebe9;
#     border-radius: 6px;
#     box-shadow: 0 3px 12px rgba(0,0,0,0.12);
#     padding: 8px;
#     display: none;
#     z-index: 20;
#     min-width: 160px;
# }
# .filter-menu-btn {
#     width: 100%;
#     background: transparent;
#     border: none;
#     text-align: left;
#     padding: 8px 10px;
#     border-radius: 4px;
#     cursor: pointer;
#     font-weight: 600;
#     color: #323130;
# }
# .filter-menu-btn:hover {
#     background: #f3f2f1;
# }
# .filter-menu-empty {
#     padding: 8px 10px;
#     font-size: 12px;
#     color: #8a8886;
#     font-weight: 600;
# }
# .filter-chip {
#     display: inline-flex;
#     align-items: center;
#     gap: 8px;
#     padding: 6px 8px;
#     border: 1px solid #edebe9;
#     border-radius: 4px;
#     background: #ffffff;
#     box-shadow: 0 1px 2px rgba(0,0,0,0.06);
# }
# .filter-chip-label {
#     font-size: 12px;
#     font-weight: 700;
#     color: #323130;
# }
# .filter-select {
#     border: 1px solid #edebe9;
#     border-radius: 6px;
#     padding: 4px 8px;
#     font-size: 12px;
#     background: #ffffff;
#     color: #323130;
#     transition: border-color 0.2s, background 0.2s, color 0.2s;
# }
# .filter-select:hover,
# .filter-select:focus {
#     border-color: #117865;
#     background: #ffffff;
#     color: #323130;
#     outline: none;
# }
# .filter-select option:hover {
#     background: #117865;
#     color: #ffffff;
# }
# .filter-chip-remove {
#     background: transparent;
#     border: none;
#     font-size: 14px;
#     cursor: pointer;
#     color: #605e5c;
#     padding: 0 4px;
# }
# .filter-chip-remove:hover {
#     color: #323130;
# }
#
# /* Toggle button group */
# .filters-row {
#     display: inline-flex;
#     align-items: center;
#     gap: 12px;
#     margin-bottom: 20px;
#     flex-wrap: wrap;
#     padding: 6px 6px;
#     border: 1px solid #e1dfdd;
#     border-radius: 6px;
#     background: #ffffff;
#     width: fit-content;
# }
# .group-by-label {
#     font-size: 13px;
#     font-weight: 600;
#     color: #323130;
#     line-height: 1.4;
# }
# .toggle-group {
#     display: inline-flex;
#     border: 1px solid #d2d0ce;
#     border-radius: 6px;
#     overflow: hidden;
#     height: 32px;
# }
# .toggle-group.compact {
#     border-color: #edebe9;
#     border-radius: 6px;
# }
# .toggle-group button {
#     background: #fafafa;
#     color: #323130;
#     border: none;
#     padding: 6px 16px;
#     font-size: 13px;
#     font-weight: 600;
#     cursor: pointer;
#     transition: all 0.2s;
#     border-right: 1px solid #d2d0ce;
#     height: 100%;
# }
# .toggle-group.compact button {
#     padding: 6px 12px;
#     min-width: 0;
# }
# .toggle-group button:last-child {
#     border-right: none;
# }
# .toggle-group button.active {
#     background: linear-gradient(135deg, #117865 0%, #0C695A 100%);
#     color: white;
# }
# .toggle-group button:hover:not(.active) {
#     background: #ffffff;
# }
#
# /* Tag filter pills */
# .tag-filters {
#     display: flex;
#     flex-wrap: wrap;
#     gap: 10px;
#     margin: 0;
# }
# .tag-filter-row {
#     margin-bottom: 40px;
# }
# .tag-filter-btn {
#     background: transparent;
#     color: #323130;
#     border: 1px solid #d2d0ce;
#     padding: 6px 18px;
#     border-radius: 4px;
#     font-size: 13px;
#     font-weight: 500;
#     cursor: pointer;
#     transition: all 0.2s;
# }
# .tag-filter-btn:hover {
#     background: #ffffff;
#     border-color: #8a8886;
# }
# .tag-filter-btn.active {
#     background: linear-gradient(135deg, #117865 0%, #0C695A 100%);
#     color: white;
#     border-color: transparent;
# }
#
# .type-pill {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 3px 8px;
#     border-radius: 999px;
#     font-size: 12px;
#     font-weight: 600;
#     background: #e6f4ef;
#     color: #0C695A;
#     border: 1px solid #b8e0d2;
#     width: fit-content;
#     margin: 0;
#     letter-spacing: 0.1px;
# }
#
# .duration-pill {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 3px 8px;
#     border-radius: 999px;
#     font-size: 12px;
#     font-weight: 600;
#     background: #eef6ff;
#     color: #0f4f8f;
#     border: 1px solid #d5e8ff;
#     width: fit-content;
#     margin: 0;
#     letter-spacing: 0.1px;
# }
#
# .deploy-pill {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 3px 8px;
#     border-radius: 999px;
#     font-size: 12px;
#     font-weight: 600;
#     background: #f7f0e6;
#     color: #7b4b06;
#     border: 1px solid #e2c79b;
#     width: fit-content;
#     margin: 0;
#     letter-spacing: 0.1px;
# }
#
# .meta-pills {
#     display: flex !important;
#     align-items: center;
#     flex-wrap: wrap;
#     gap: 8px;
#     margin-bottom: 12px;
#     min-height: 24px;
# }
# .category-section {
#     margin-bottom: 56px;
# }
# .category-section.hidden {
#     display: none;
# }
# .category-label {
#     color: #117865;
#     font-size: 16px;
#     font-weight: 600;
#     text-transform: uppercase;
#     letter-spacing: 2.25px;
#     margin-bottom: 4px;
# }
# .category-title {
#     color: #1f1f1f;
#     font-size: 24px;
#     font-weight: 700;
#     margin: 0 0 30px 0;
#     line-height: 1.2;
# }
# .jumpstart-grid {
#     display: grid;
#     grid-template-columns: repeat(auto-fill, minmax(300px, 1fr));
#     gap: 24px;
#     margin-bottom: 16px;
# }
# .jumpstart-card {
#     background: #ffffff;
#     border: 1px solid #edebe9;
#     border-radius: 4px;
#     overflow: hidden;
#     transition: all 0.3s ease;
#     box-shadow: 0 1.6px 3.6px 0 rgba(0,0,0,.132), 0 0.3px 0.9px 0 rgba(0,0,0,.108);
#     display: flex;
#     flex-direction: column;
#     position: relative;
#     --accent-primary: #117865;
#     --accent-secondary: #0C695

# %%
import importlib
import fabric_jumpstart as jumpstart
importlib.reload(jumpstart.ui)
importlib.reload(jumpstart.core)
importlib.reload(jumpstart.response)
importlib.reload(jumpstart.utils)
importlib.reload(jumpstart)
jumpstart.ui.reload_assets()

# %%
jumpstart.install('analytics-lab', workspace_id='31fd6347-72d9-469d-9b6f-57b31ad93524', debug=True)
# Out:
# <style>.install-status-card {
#     border: 1px solid #edebe9;
#     border-radius: 10px;
#     padding: 16px;
#     margin: 12px 0;
#     background: #ffffff;
#     box-shadow: 0 8px 24px rgba(0, 0, 0, .12);
#     font-family: "Segoe UI", Helvetica, Arial, sans-serif;
#     color: #1f1f1f;
#     position: relative;
#     overflow: hidden;
# }
#
# .install-status-card.success::before {
#     content: "";
#     position: absolute;
#     inset: -30% -10%;
#     background: radial-gradient(circle at 40% 30%, rgba(17, 120, 101, 0.02), transparent 55%), radial-gradient(circle at 80% 20%, rgba(15, 79, 143, 0.02), transparent 45%);
#     z-index: 0;
# }
#
# .install-status-card.error::before {
#     content: "";
#     position: absolute;
#     inset: -40% -20%;
#     background: radial-gradient(circle at 30% 30%, rgba(164, 38, 44, 0.08), transparent 45%), radial-gradient(circle at 80% 20%, rgba(255, 141, 141, 0.08), transparent 35%);
#     z-index: 0;
# }
#
# .install-status-card>* {
#     position: relative;
#     z-index: 1;
# }
#
# .install-hero {
#     display: flex;
#     align-items: center;
#     justify-content: space-between;
#     gap: 16px;
#     padding: 14px 16px;
#     border-radius: 10px;
#     margin-bottom: 12px;
#     box-shadow: 0 4px 14px rgba(0, 0, 0, 0.08);
# }
#
# .install-hero.success {
#     background: #f6fbf9;
#     color: #0f5246;
#     border: 1px solid #d5ebe2;
# }
#
# .install-hero.success .hero-kicker {
#     color: #0f5246;
#     opacity: 0.8;
# }
#
# .install-hero.success .hero-meta {
#     color: #0f5246
# }
#
# .install-cta {
#     border: 1px solid #0c695a;
#     background: linear-gradient(135deg, #0f9d8c, #0c695a);
#     color: #ffffff !important;
# }
#
# .install-hero.error {
#     background: linear-gradient(135deg, #d64545, #a4262c);
#     color: #ffffff;
# }
#
# .hero-icon {
#     font-size: 28px;
#     line-height: 1;
#     filter: drop-shadow(0 2px 4px rgba(0, 0, 0, 0.18));
# }
#
# .hero-text {
#     flex: 1;
#     min-width: 0;
# }
#
# .hero-kicker {
#     text-transform: uppercase;
#     letter-spacing: 0.8px;
#     font-size: 11px;
#     font-weight: 700;
#     opacity: 0.9;
# }
#
# .hero-title {
#     font-size: 18px;
#     font-weight: 800;
#     margin: 2px 0;
# }
#
# .hero-title.category-title {
#     color: #1f1f1f;
#     font-size: 24px;
#     font-weight: 700;
# }
#
# .hero-kicker.category-label {
#     color: #117865;
#     font-size: 16px;
#     text-transform: uppercase;
#     letter-spacing: 2.25px;
#     font-weight: 600;
#     opacity: 1;
# }
#
# .hero-sub {
#     color: #1f1f1f;
# }
#
# .hero-meta {
#     color: #1f1f1f;
# }
#
# .hero-sub {
#     font-size: 13px;
#     opacity: 0.9;
# }
#
# .hero-meta {
#     margin-top: 4px;
#     font-size: 12px;
#     opacity: 0.9;
# }
#
# .hero-cta {
#     display: flex;
#     align-items: center;
#     gap: 8px;
#     flex-wrap: wrap;
#     justify-content: flex-end;
# }
#
# .install-cta {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 8px 12px;
#     border-radius: 8px;
#     background: linear-gradient(135deg, #0f9d8c, #0c695a);
#     color: #ffffff !important;
#     font-weight: 700;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.16);
#     text-decoration: none;
#     border: 1px solid #0c695a;
# }
#
# .install-cta:hover {
#     transform: translateY(-1px);
#     text-decoration: none;
#     filter: brightness(1.03);
# }
#
# .install-cta.secondary {
#     background: #f7fbf9;
#     color: #0c695a !important;
#     border: 1px solid #b8dcd0;
#     box-shadow: 0 2px 6px rgba(0, 0, 0, 0.06);
# }
#
# .install-cta.secondary:hover {
#     filter: none;
#     transform: translateY(-1px);
#     background: #eef7f2;
# }
#
# .install-cta svg {
#     width: 14px;
#     height: 14px;
# }
#
# .install-hero.success .hero-icon {
#     animation: pop 0.6s ease;
# }
#
# @keyframes pop {
#     0% {
#         transform: scale(0.8);
#     }
#
#     60% {
#         transform: scale(1.08);
#     }
#
#     100% {
#         transform: scale(1);
#     }
# }
#
# .install-status-header {
#     display: flex;
#     align-items: center;
#     justify-content: space-between;
#     gap: 12px;
#     margin-bottom: 12px;
#     flex-wrap: wrap;
# }
#
# .install-status-header {
#     display: flex;
#     align-items: center;
#     justify-content: space-between;
#     gap: 12px;
#     margin-bottom: 16px;
#     flex-wrap: wrap;
# }
#
# .install-status-title {
#     font-size: 18px;
#     font-weight: 700;
#     margin: 0;
# }
#
# .install-status-subtitle {
#     font-size: 13px;
#     color: #605e5c;
#     margin: 0;
# }
#
# .install-status-pill {
#     display: inline-flex;
#     align-items: center;
#     gap: 8px;
#     padding: 6px 10px;
#     border-radius: 999px;
#     font-size: 12px;
#     font-weight: 700;
#     letter-spacing: 0.2px;
#     text-transform: uppercase;
#     box-shadow: 0 6px 14px rgba(0, 0, 0, 0.08);
# }
#
# .install-status-pill.success {
#     background: #e6f4ef;
#     color: #0C695A;
#     border: 1px solid #b8e0d2;
# }
#
# .install-status-pill.info {
#     background: #eef6ff;
#     color: #0f4f8f;
#     border: 1px solid #d5e8ff;
# }
#
# .install-status-pill.error {
#     background: #fde7e9;
#     color: #a4262c;
#     border: 1px solid #f4afb4;
# }
#
# .install-status-pill.installing {
#     gap: 6px;
# }
#
# .install-status-pill.installing .pill-icon {
#     font-weight: 700;
#     line-height: 1;
# }
#
# .install-status-pill.installing .pill-label {
#     font-weight: 700;
#     letter-spacing: 0.2px;
# }
#
# .install-status-pill.installing .pill-dots {
#     display: inline-flex;
#     align-items: center;
#     gap: 3px;
# }
#
# .install-status-pill.installing .pill-dot {
#     width: 6px;
#     height: 6px;
#     border-radius: 999px;
#     background: currentColor;
#     opacity: 0.35;
#     animation: install-dots 1.1s infinite ease-in-out;
# }
#
# .install-status-pill.installing .pill-dot:nth-child(2) {
#     animation-delay: 0.12s;
# }
#
# .install-status-pill.installing .pill-dot:nth-child(3) {
#     animation-delay: 0.24s;
# }
#
# @keyframes install-dots {
#     0%, 80%, 100% {
#         transform: scale(0.65);
#         opacity: 0.35;
#     }
#     40% {
#         transform: scale(1.15);
#         opacity: 1;
#     }
# }
#
# .install-status-grid {
#     display: grid;
#     grid-template-columns: repeat(auto-fit, minmax(220px, 1fr));
#     gap: 12px;
#     margin-top: 12px;
# }
#
# .install-status-item {
#     border: 1px solid #f3f2f1;
#     border-radius: 6px;
#     padding: 10px 12px;
#     background: #faf9f8;
# }
#
# .install-status-label {
#     font-size: 12px;
#     color: #1f1f1f;
#     margin-bottom: 4px;
#     font-weight: 600;
# }
#
# .install-status-value {
#     font-size: 14px;
#     font-weight: 600;
#     word-break: break-word;
#     color: #1f1f1f;
# }
#
# .install-status-value a {
#     color: #0f4f8f;
#     text-decoration: none;
# }
#
# .install-status-value a:hover {
#     text-decoration: underline;
# }
#
# .install-status-link {
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 6px 10px;
#     border-radius: 6px;
#     background: linear-gradient(135deg, #117865 0%, #0C695A 100%);
#     color: #ffffff !important;
#     font-weight: 500;
#     box-shadow: 0 1px 2px rgba(0, 0, 0, 0.12);
# }
#
# .install-status-link:hover {
#     text-decoration: none;
#     filter: brightness(1.05);
# }
#
# .install-status-link svg {
#     width: 14px;
#     height: 14px;
# }
#
# .install-status-error {
#     margin-top: 12px;
#     padding: 10px 12px;
#     border-radius: 6px;
#     border: 1px solid #f4afb4;
#     background: #fde7e9;
#     color: #a4262c;
#     font-size: 13px;
#     word-break: break-word;
# }
#
# .install-status-section {
#     margin-top: 12px;
# }
#
# .install-status-section-title {
#     font-size: 14px;
#     font-weight: 600;
#     color: #323130;
#     letter-spacing: 0.1px;
#     margin: 0 0 8px 0;
# }
#
# .install-status-grid.tight {
#     grid-template-columns: repeat(auto-fit, minmax(200px, 1fr));
# }
#
# .install-status-logs {
#     margin-top: 12px;
#     border: 1px solid #edebe9;
#     border-radius: 6px;
#     background: #faf9f8;
#     padding: 10px 12px;
#     box-shadow: 0 1px 2px rgba(0, 0, 0, 0.06);
# }
#
# /* moved down */
# .install-status-logs details {
#     border: 1px solid #edebe9;
#     border-radius: 6px;
#     background: #ffffff;
#     padding: 8px 10px;
#     max-height: 700px;
#     overflow-y: auto;
#     overflow-x: hidden;
#     overscroll-behavior: contain;
#     scrollbar-width: auto;
#     scrollbar-color: #0C695A #e6f4ef;
# }
#
# .install-status-logs details::-webkit-scrollbar {
#     width: 12px;
# }
#
# .install-status-logs details::-webkit-scrollbar-tra
