# %% [markdown]
# > Do not commit changes to this file. Instead, make a copy of this Notebook for development and testing purposes into the `dev/` folder. Other files in the `dev/` folder are not committed to GitHub.

# %%
import importlib
import fabric_jumpstart as jumpstart

# Reload all modules including new ones
importlib.reload(jumpstart.logger)
importlib.reload(jumpstart.registry)
importlib.reload(jumpstart.workspace_manager)
importlib.reload(jumpstart.installer)
importlib.reload(jumpstart.ui)
importlib.reload(jumpstart.core)
jumpstart.list(show_unlisted=True)
# Out:
# The kernel failed to start due to the missing module 'comm'. Consider installing this module.
#
# Click <a href='https://aka.ms/kernelFailuresMissingModule'>here</a> for more info.

# %%
## jumpstart.install("lakebench-tpcds", workspace_id="5ad9fe70-998b-4bff-891f-d500dd3947a8", force=True)
jumpstart.install("warehouse-demo-labs", workspace_id="5ad9fe70-998b-4bff-891f-d500dd3947a8", force=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 2
#       1 ## jumpstart.install("lakebench-tpcds", workspace_id="5ad9fe70-998b-4bff-891f-d500dd3947a8", force=True)
# ----> 2 jumpstart.install("warehouse-demo-labs", workspace_id="5ad9fe70-998b-4bff-891f-d500dd3947a8", force=True)
#
# File C:\dev\jumpstart-demo\fabric-jumpstart\src\fabric_jumpstart\fabric_jumpstart\core.py:190, in jumpstart.install(self, name, workspace_id, **kwargs)
#     188 if not config:
#     189     error_msg = f"Unknown jumpstart '{name}'. Use fabric_jumpstart.list() to list available jumpstarts."
# --> 190     raise ValueError(error_msg)
#     191 return self._install_with_config(config, workspace_id, **kwargs)
#
# ValueError: Unknown jumpstart 'warehouse-demo-labs'. Use fabric_jumpstart.list() to list available jumpstarts.

# %%
jumpstart.install("warehouse-demo-labs", workspace_id="5ad9fe70-998b-4bff-891f-d500dd3947a8")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 jumpstart.install("warehouse-demo-labs", workspace_id="5ad9fe70-998b-4bff-891f-d500dd3947a8")
#
# File C:\dev\jumpstart-demo\fabric-jumpstart\src\fabric_jumpstart\fabric_jumpstart\core.py:190, in jumpstart.install(self, name, workspace_id, **kwargs)
#     188 if not config:
#     189     error_msg = f"Unknown jumpstart '{name}'. Use fabric_jumpstart.list() to list available jumpstarts."
# --> 190     raise ValueError(error_msg)
#     191 return self._install_with_config(config, workspace_id, **kwargs)
#
# ValueError: Unknown jumpstart 'warehouse-demo-labs'. Use fabric_jumpstart.list() to list available jumpstarts.
